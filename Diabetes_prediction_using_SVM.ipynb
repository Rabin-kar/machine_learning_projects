# %% [markdown]
# <a href="https://colab.research.google.com/github/Rabin-kar/machine_learning_projects/blob/main/Diabetes_prediction_using_SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data collection And analysis

# %%
#loading the diabetes dataset to a pandas dataframe
dataset = pd.read_csv('/content/Updated_diabetes_dataset.csv')

# %%
# printing the first 5 rows of the dataset
dataset.head()
# Out:
#    gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0     0.0  80.0             0              1              0.0  25.19
# 1     0.0  54.0             0              0              NaN  27.32
# 2     1.0  28.0             0              0              0.0  27.32
# 3     0.0  36.0             0              0              1.0  23.45
# 4     1.0  76.0             1              1              1.0  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
# number of rows and columns in this dataset
dataset.shape
# Out:
# (100000, 9)

# %%
dataset.isnull()
# Out:
#        gender    age  hypertension  heart_disease  smoking_history    bmi  \
# 0       False  False         False          False            False  False
# 1       False  False         False          False             True  False
# 2       False  False         False          False            False  False
# 3       False  False         False          False            False  False
# 4       False  False         False          False            False  False
# ...       ...    ...           ...            ...              ...    ...
# 99995   False  False         False          False             True  False
# 99996   False  False         False          False             True  False
# 99997   False  False         False          False            False  False
# 99998   False  False         False          False            False  False
# 99999   False  False         False          False            False  False
#
#        HbA1c_level  blood_glucose_level  diabetes
# ...

# %%
new_dataset=dataset.fillna(value=dataset['gender'].mean())
new_dataset.fillna(value=new_dataset['smoking_history'].mean())
new_dataset
# Out:
#        gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0         0.0  80.0             0              1         0.000000  25.19
# 1         0.0  54.0             0              0         0.414375  27.32
# 2         1.0  28.0             0              0         0.000000  27.32
# 3         0.0  36.0             0              0         1.000000  23.45
# 4         1.0  76.0             1              1         1.000000  20.14
# ...       ...   ...           ...            ...              ...    ...
# 99995     0.0  80.0             0              0         0.414375  27.32
# 99996     0.0   2.0             0              0         0.414375  17.37
# 99997     1.0  66.0             0              0         1.000000  27.83
# 99998     0.0  24.0             0              0         0.000000  35.42
# 99999     0.0  57.0             0              0         1.000000  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# ...

# %%
new_dataset.drop_duplicates(inplace=True)
new_dataset
# Out:
#        gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0         0.0  80.0             0              1         0.000000  25.19
# 1         0.0  54.0             0              0         0.414375  27.32
# 2         1.0  28.0             0              0         0.000000  27.32
# 3         0.0  36.0             0              0         1.000000  23.45
# 4         1.0  76.0             1              1         1.000000  20.14
# ...       ...   ...           ...            ...              ...    ...
# 99994     0.0  36.0             0              0         0.414375  24.60
# 99996     0.0   2.0             0              0         0.414375  17.37
# 99997     1.0  66.0             0              0         1.000000  27.83
# 99998     0.0  24.0             0              0         0.000000  35.42
# 99999     0.0  57.0             0              0         1.000000  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# ...

# %%
new_dataset.shape
# Out:
# (95715, 9)

# %%
# getting the statistical measures of the data
new_dataset.describe()
# Out:
#               gender            age  hypertension  heart_disease  \
# count  100000.000000  100000.000000  100000.00000  100000.000000
# mean        0.414375      41.885856       0.07485       0.039420
# std         0.492572      22.516840       0.26315       0.194593
# min         0.000000       0.080000       0.00000       0.000000
# 25%         0.000000      24.000000       0.00000       0.000000
# 50%         0.000000      43.000000       0.00000       0.000000
# 75%         1.000000      60.000000       0.00000       0.000000
# max         1.000000      80.000000       1.00000       1.000000
#
#        smoking_history            bmi    HbA1c_level  blood_glucose_level  \
# count    100000.000000  100000.000000  100000.000000        100000.000000
# mean          0.439302      27.320767       5.527507           138.058060
# std           0.399253       6.636783       1.070672            40.708136
# min           0.000000      10.010000       3.500000            80.000000
# ...

# %%
new_dataset['diabetes'].value_counts()
# Out:
# 0    87237
# 1     8478
# Name: diabetes, dtype: int64

# %% [markdown]
# 0--> Non diabetic
#
# 1--> Diabetic

# %%
# seperating data and label
X = new_dataset.drop(['gender','hypertension','smoking_history','diabetes'],axis=1)
Y = new_dataset['diabetes']

# %%
print(X)
# Out:
#         age  heart_disease    bmi  HbA1c_level  blood_glucose_level
# 0      80.0              1  25.19          6.6                  140
# 1      54.0              0  27.32          6.6                   80
# 2      28.0              0  27.32          5.7                  158
# 3      36.0              0  23.45          5.0                  155
# 4      76.0              1  20.14          4.8                  155
# ...     ...            ...    ...          ...                  ...
# 99994  36.0              0  24.60          4.8                  145
# 99996   2.0              0  17.37          6.5                  100
# 99997  66.0              0  27.83          5.7                  155
# 99998  24.0              0  35.42          4.0                  100
# 99999  57.0              0  22.43          6.6                   90
#
# [95715 rows x 5 columns]

# %%
print(Y)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99994    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: diabetes, Length: 95715, dtype: int64

# %% [markdown]
# Data standardization

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(X)

# %%
print(standardized_data)
# Out:
# [[ 1.70119972e+00  4.83912098e+00 -3.14228575e-01  9.93819773e-01
#    4.30818268e-02]
#  [ 5.44390416e-01 -2.06649101e-01 -1.99347989e-04  9.93819773e-01
#   -1.42280961e+00]
#  [-6.12418886e-01 -2.06649101e-01 -1.99347989e-04  1.55447750e-01
#    4.82849259e-01]
#  ...
#  [ 1.07830240e+00 -2.06649101e-01  7.49907487e-02  1.55447750e-01
#    4.09554687e-01]
#  [-7.90389547e-01 -2.06649101e-01  1.19399631e+00 -1.42814385e+00
#   -9.34179133e-01]
#  [ 6.77868412e-01 -2.06649101e-01 -7.21139687e-01  9.93819773e-01
#   -1.17849437e+00]]

# %%
X=standardized_data
Y=new_dataset['diabetes']

# %%
print(X)
print(Y)
# Out:
# [[ 1.70119972e+00  4.83912098e+00 -3.14228575e-01  9.93819773e-01
#    4.30818268e-02]
#  [ 5.44390416e-01 -2.06649101e-01 -1.99347989e-04  9.93819773e-01
#   -1.42280961e+00]
#  [-6.12418886e-01 -2.06649101e-01 -1.99347989e-04  1.55447750e-01
#    4.82849259e-01]
#  ...
#  [ 1.07830240e+00 -2.06649101e-01  7.49907487e-02  1.55447750e-01
#    4.09554687e-01]
#  [-7.90389547e-01 -2.06649101e-01  1.19399631e+00 -1.42814385e+00
#   -9.34179133e-01]
#  [ 6.77868412e-01 -2.06649101e-01 -7.21139687e-01  9.93819773e-01
#   -1.17849437e+00]]
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99994    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: diabetes, Length: 95715, dtype: int64

# %% [markdown]
# Train Test Split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (95715, 5) (76572, 5) (19143, 5)

# %% [markdown]
# Training the model

# %%
classifier = svm.SVC(kernel='linear')

# %%
# training the svm classifier
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# Model evaluation
#
# Accuracy score

# %%
# accuracy score on the training data
X_train_predection = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_predection, Y_train)

# %%
print("Accuracy score of the training data: ", training_data_accuracy)
# Out:
# Accuracy score of the training data:  0.9586794128402026

# %%
#accuracy score on the test data
X_test_predection = classifier.predict(X_test)
test_data_accuracy = accuracy_score(X_test_predection, Y_test)

# %%
print("Accuracy score of the test data: ", test_data_accuracy)
# Out:
# Accuracy score of the test data:  0.9592017970015149

# %% [markdown]
# Creating a predective system

# %%
input_data=()
#change the input_data as numpy array

input_data_as_numpy_array = np.asarray(input_data)

#reshape the array because we are predicting only one instance

input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

#standradized the input_data

std_data = scaler.transform(input_data_reshaped)
print(std_data)

prediction = classifier.predict(std_data)

print(prediction)

if(prediction[0] == 0):
  print("The person is non diabetic!")
else:
  print("The person is diabetic....!!")
# Out:
# [[ 1.12279507 -0.2066491  -3.88059806 20.29500678 -3.21852663]]
# [1]
# The person is diabetic....!!
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
